# %%
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("/home/bartu/Downloads/TF_2_Notebooks_and_Data/DATA/iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = iris.drop("species", axis = 1)

# %%
y = iris["species"]

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
encoder = LabelBinarizer()

# %%
y = encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
scaled_X_train = scaler.transform(X_train)

# %%
scaled_X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units = 4, activation = "relu", input_shape = [4, ]))
model.add(Dense(units = 3, activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(patience = 10)

# %%
model.fit(x = scaled_X_train, y = y_train, epochs = 700, validation_data = (scaled_X_test, y_test), callbacks = [early_stop])
# Out:
# Epoch 1/700
# 4/4 [==============================] - 0s 26ms/step - loss: 1.0819 - accuracy: 0.3500 - val_loss: 1.0861 - val_accuracy: 0.3333
# Epoch 2/700
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0800 - accuracy: 0.3583 - val_loss: 1.0846 - val_accuracy: 0.3333
# Epoch 3/700
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0782 - accuracy: 0.3667 - val_loss: 1.0834 - val_accuracy: 0.3333
# Epoch 4/700
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0765 - accuracy: 0.3667 - val_loss: 1.0822 - val_accuracy: 0.3333
# Epoch 5/700
# 4/4 [==============================] - 0s 5ms/step - loss: 1.0749 - accuracy: 0.3667 - val_loss: 1.0810 - val_accuracy: 0.3333
# Epoch 6/700
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0732 - accuracy: 0.3750 - val_loss: 1.0797 - val_accuracy: 0.4333
# Epoch 7/700
# ...

# %%
metrics = pd.DataFrame(model.history.history)

# %%
metrics[["loss", "val_loss"]].plot()
# Out:
# <AxesSubplot:>

# %%
metrics[["accuracy", "val_accuracy"]].plot()
# Out:
# <AxesSubplot:>

# %%
model.evaluate(scaled_X_test, y_test, verbose = 0)
# Out:
# [0.1605900377035141, 0.9333333373069763]

# %%
scaled_X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(units = 4, activation = "relu", input_shape = [4, ]))
model.add(Dense(units = 3, activation = "softmax"))

model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
model.fit(scaled_X, y, epochs = 700)
# Out:
# Epoch 1/700
# 5/5 [==============================] - 0s 1ms/step - loss: 1.1055 - accuracy: 0.6000
# Epoch 2/700
# 5/5 [==============================] - 0s 722us/step - loss: 1.1019 - accuracy: 0.6067
# Epoch 3/700
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0986 - accuracy: 0.6200
# Epoch 4/700
# 5/5 [==============================] - 0s 747us/step - loss: 1.0949 - accuracy: 0.6267
# Epoch 5/700
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0914 - accuracy: 0.6267
# Epoch 6/700
# 5/5 [==============================] - 0s 901us/step - loss: 1.0878 - accuracy: 0.6333
# Epoch 7/700
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0844 - accuracy: 0.6467
# Epoch 8/700
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0809 - accuracy: 0.6533
# Epoch 9/700
# 5/5 [==============================] - 0s 652us/step - loss: 1.0775 - accuracy: 0.6600
# Epoch 10/700
# ...

# %%
model.save("final_iris_model.h5")

# %%
import joblib

# %%
joblib.dump(scaler, "iris_scaler.pkl")
# Out:
# ['iris_scaler.pkl']

# %%
from tensorflow.keras.models import load_model

# %%
flower_model = load_model("final_iris_model.h5")

# %%
flower_scaler = joblib.load("iris_scaler.pkl")

# %%
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
flower_example = {"sepal_length" : 5.1,
                  "sepal_width" : 3.5,
                  "petal_length" : 1.4,
                  "petal_width" : 0.2}

# %%
def return_prediction(model, scaler, sample_json):
    s_len = sample_json["sepal_length"]
    s_wid = sample_json["sepal_width"]
    p_len = sample_json["petal_length"]
    p_wid = sample_json["petal_width"]

    flower = [[s_len, s_wid, p_len, p_wid]]

    classes = np.array(["setosa", "versicolor", "virginica"])

    flower = scaler.transform(flower)

    class_ind = model.predict_classes(flower)

    return classes[class_ind][0]

# %%
return_prediction(flower_model, flower_scaler, flower_example)
# Out:
# 'setosa'
